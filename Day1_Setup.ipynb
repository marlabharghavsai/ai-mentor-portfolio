# %% [markdown]
# <a href="https://colab.research.google.com/github/marlabharghavsai/ai-mentor-portfolio/blob/main/Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid outlines the necessary competencies for building and managing AI solutions, from technical foundations to strategic oversight:
#
# *   **Data Science & ML Engineering:** The foundational layers, focusing on collecting, cleaning, and preparing data, along with building, training, and deploying core machine learning models.
# *   **AI Solution Development:** Integrating AI models into complete, user-facing applications and systems, ensuring functionality and user experience.
# *   **AI Ethics & Governance:** Addressing the responsible development, fairness, privacy, security, and compliance aspects of AI systems.
# *   **AI Strategy & Leadership:** Defining the vision, business value, investment, and organizational impact of AI initiatives at a strategic level.

# %%
from google.colab import drive
drive.mount('/content/drive')
